# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
import pandas as pd
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
filtered_hygiene_query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
establishments.count_documents(filtered_hygiene_query)
# Display the first document in the results using pprint
pprint(establishments.find_one(filtered_hygiene_query))
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f0bd95491ed8d22b6d9e88'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
# ...

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(establishments.find(filtered_hygiene_query))
# Display the number of rows in the DataFrame
df.shape[0]
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f0bd95491ed8d22b6d9e88   110681                  0
# 1  64f0bd95491ed8d22b6da21a   612039                  0
# 2  64f0bd95491ed8d22b6da514   730933                  0
# 3  64f0bd95491ed8d22b6da6ff   172735                  0
# 4  64f0bd95491ed8d22b6da70c   172953                  0
# 5  64f0bd95491ed8d22b6db0ab   512854                  0
# 6  64f0bd95491ed8d22b6db2d1  1537089                  0
# 7  64f0bd96491ed8d22b6dc7fb   155648                  0
# 8  64f0bd96491ed8d22b6dcc3f  1012883                  0
# 9  64f0bd96491ed8d22b6dd452   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
london_establishments_query = {"$and":[{'AddressLine3': 'London'},{'RatingValue': {'$gte': 4}}]}

# Use count_documents to display the number of documents in the result
establishments.count_documents(london_establishments_query)

# Display the first document in the results using pprint
pprint(establishments.find_one(london_establishments_query))
# Out:
# {'AddressLine1': '75 Woolwich Road',
#  'AddressLine2': 'Abbey Wood',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'The Croft Day Nursery',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4645.185333904148,
#  'FHRSID': 329113,
#  'LocalAuthorityBusinessID': '03260/0075/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE2 0DY',
#  'RatingDate': '2019-09-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f0bd96491ed8d22b6dee60'),
#  'geocode': {'latitude': Decimal128('51.482981'),
#              'longitude': Decimal128('0.136519')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/329113',
# ...

# %%
# Convert the result to a Pandas DataFrame
df2 = pd.DataFrame(establishments.find(london_establishments_query))

# Display the number of rows in the DataFrame
df2.shape[0]

# Display the first 10 rows of the DataFrame
df2.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f0bd96491ed8d22b6dee60   329113                  0
# 1  64f0bd96491ed8d22b6dee61   329114                  0
# 2  64f0bd96491ed8d22b6defc1  1402880                  0
# 3  64f0bd96491ed8d22b6df069   975472                  0
# 4  64f0bd96491ed8d22b6df06a  1262185                  0
# 5  64f0bd96491ed8d22b6df1d5   687040                  0
# 6  64f0bd96491ed8d22b6df1e6   610394                  0
# 7  64f0bd96491ed8d22b6df23f  1109051                  0
# 8  64f0bd96491ed8d22b6df269  1385124                  0
# 9  64f0bd96491ed8d22b6df307  1256695                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0         03260/0075/0/000                              The Croft Day Nursery
# 1         03260/2001/2/000                     Belvedere Sports & Social Club
# 2              21/00281/CP  Independent Catering Management At Dulverton P...
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {'geocode.latitude': {'$gte': latitude-degree_search + degree_search, '$lte': latitude+degree_search}, 
         'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},'RatingValue': 5}

sort =  [('scores.Hygiene', 1)]
limit = 5

# Print the results
pprint(list(establishments.find(query).sort(sort).limit(limit)))
# Out:
# [{'AddressLine1': '7 - 8 Thames Reach',
#   'AddressLine2': '',
#   'AddressLine3': 'Thamesmead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Tesco',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4647.459121108046,
#   'FHRSID': 695003,
#   'LocalAuthorityBusinessID': 'PI/000171503',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE28 0NY',
#   'RatingDate': '2020-02-22T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64f0bd96491ed8d22b6df9af'),
#   'geocode': {'latitude': Decimal128('51.4989512'),
#               'longitude': Decimal128('0.0902181')},
# ...

# %%
# Convert result to Pandas DataFrame
df3 = pd.DataFrame(establishments.find(query))
df3.head()
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f0bd96491ed8d22b6df95b   695316                  0
# 1  64f0bd96491ed8d22b6df96c  1319113                  0
# 2  64f0bd96491ed8d22b6df996  1392055                  0
# 3  64f0bd96491ed8d22b6df9af   695003                  0
# 4  64f0bd96491ed8d22b6df9ba   695236                  0
#
#   LocalAuthorityBusinessID              BusinessName  \
# 0             PI/000182673                McDonald's
# 1                    14007          Suya Academy Ltd
# 2                    14546  Greenwich Islamic Centre
# 3             PI/000171503                     Tesco
# 4             PI/000179022            Domino's Pizza
#
#                             BusinessType  BusinessTypeID        AddressLine1  \
# 0                Restaurant/Cafe/Canteen               1  3 Pettman Crescent
# 1                Restaurant/Cafe/Canteen               1  148 Plumstead Road
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {'$match': {'scores.Hygiene':0}}
group_query = {'$group': {'_id':'$LocalAuthorityCode', 
                          'count': {'$sum': 1}}}
sort_values = {'$sort': {'count': -1}}

pipeline = [match_query, group_query,sort_values]
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Number of documents in the result: ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of documents in the result:  55
# [{'_id': '190', 'count': 1130},
#  {'_id': '511', 'count': 882},
#  {'_id': '185', 'count': 713},
#  {'_id': '525', 'count': 711},
#  {'_id': '189', 'count': 686},
#  {'_id': '113', 'count': 680},
#  {'_id': '896', 'count': 672},
#  {'_id': '503', 'count': 607},
#  {'_id': '893', 'count': 586},
#  {'_id': '120', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
df4 = pd.DataFrame(establishments.find(query))

# Display the number of rows in the DataFrame
df4.shape[0]

# Display the first 10 rows of the DataFrame
df4.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f0bd96491ed8d22b6df95b   695316                  0
# 1  64f0bd96491ed8d22b6df96c  1319113                  0
# 2  64f0bd96491ed8d22b6df996  1392055                  0
# 3  64f0bd96491ed8d22b6df9af   695003                  0
# 4  64f0bd96491ed8d22b6df9ba   695236                  0
# 5  64f0bd96491ed8d22b6dfa10  1385143                  0
# 6  64f0bd96491ed8d22b6dfa1d   694900                  0
# 7  64f0bd96491ed8d22b6dfa21   947998                  0
# 8  64f0bd96491ed8d22b6dfa22   695385                  0
# 9  64f0bd96491ed8d22b6dfa24   695707                  0
#
#   LocalAuthorityBusinessID                                 BusinessName  \
# 0             PI/000182673                                   McDonald's
# 1                    14007                             Suya Academy Ltd
# 2                    14546                     Greenwich Islamic Centre
# ...
